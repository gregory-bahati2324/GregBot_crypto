# %%
import ccxt
import pandas as pd
import ta

# %%
exchange = ccxt.binance({
    'enableRateLimit': True,  # important to avoid ban
})

# %%
markets = exchange.load_markets()

# %%
usdt_pairs = []

for symbol, market in markets.items():
    if (
        symbol.endswith('/USDT') and
        market['spot'] and
        market['active']
    ):
        usdt_pairs.append(symbol)

print(f"Total active USDT spot pairs: {len(usdt_pairs)}")
print(usdt_pairs[:10])  # show first 10
# Out:
# Total active USDT spot pairs: 441
# ['BTC/USDT', 'ETH/USDT', 'BNB/USDT', 'NEO/USDT', 'LTC/USDT', 'QTUM/USDT', 'ADA/USDT', 'XRP/USDT', 'TUSD/USDT', 'IOTA/USDT']

# %%
filtered_pairs = [
    symbol for symbol in usdt_pairs
    if not any(x in symbol for x in ['UP/', 'DOWN/', 'BULL/', 'BEAR/'])
]

print(f"Clean USDT pairs: {len(filtered_pairs)}")
# Out:
# Clean USDT pairs: 439

# %%
def get_ohlcv(symbol, timeframe='15m', limit=200):
    ohlcv = exchange.fetch_ohlcv(symbol, timeframe=timeframe, limit=limit)
    
    df = pd.DataFrame(ohlcv, columns=[
        'timestamp','open','high','low','close','volume'
    ])
    
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    return df

# %%
import pandas as pd
import numpy as np

def add_rsi_tradingview(df, length=14, source_col='close'):
    """
    TradingView / Pine Script RSI implementation using RMA (Wilder)
    """

    # 1. Price change (ta.change)
    change = df[source_col].diff()

    # 2. Up & Down series
    up = change.clip(lower=0)
    down = -change.clip(upper=0)

    # 3. Wilder's Moving Average (RMA)
    alpha = 1 / length
    avg_up = up.ewm(alpha=alpha, adjust=False).mean()
    avg_down = down.ewm(alpha=alpha, adjust=False).mean()

    # 4. RSI calculation
    rs = avg_up / avg_down
    rsi = np.where(
        avg_down == 0, 100,
        np.where(avg_up == 0, 0, 100 - (100 / (1 + rs)))
    )

    df['rsi'] = rsi
    return df

# %%
def add_stochastic_tv(df, periodK=14, smoothK=3, periodD=3):
    
    # Raw stochastic
    low_min = df['low'].rolling(periodK).min()
    high_max = df['high'].rolling(periodK).max()
    
    stoch = 100 * (df['close'] - low_min) / (high_max - low_min)
    
    # Smooth K
    k = stoch.rolling(smoothK).mean()
    
    # Smooth D
    d = k.rolling(periodD).mean()
    
    df['stoch_k'] = k
    df['stoch_d'] = d
    
    return df

# %%
def add_stoch_rsi_tv(df, lengthRSI=14, lengthStoch=14, smoothK=3, smoothD=3):

    # --- TRUE TradingView RSI (RMA based)
    delta = df['close'].diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)

    alpha = 1 / lengthRSI
    avg_gain = gain.ewm(alpha=alpha, adjust=False).mean()
    avg_loss = loss.ewm(alpha=alpha, adjust=False).mean()

    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))

    # --- TRUE Stochastic of RSI
    rsi_min = rsi.rolling(lengthStoch).min()
    rsi_max = rsi.rolling(lengthStoch).max()

    stoch = 100 * (rsi - rsi_min) / (rsi_max - rsi_min)

    # --- Smooth K and D
    k = stoch.rolling(smoothK).mean()
    d = k.rolling(smoothD).mean()

    df['stoch_rsi_k'] = k
    df['stoch_rsi_d'] = d

    return df

# %%
df = get_ohlcv('ADA/USDT', '1d', 200)
df = add_rsi_tradingview(df)
df = add_stochastic_tv(df)
df = add_stoch_rsi_tv(df, 14, 14, 3, 3)

# %%
last = df.iloc[-1]

print("Symbol: ADA/USDT")
print("RSI:", last['rsi'])
print("stochastic RSI K", last['stoch_rsi_k']) #Required for stochastic(14, 14, 3, 3) strategy
print("stochastic %K(14, 3, 3)", last['stoch_d']) # required for stochastic%K(14,3, 3) strategy
# Out:
# Symbol: ADA/USDT
# RSI: 40.430197401370954
# stochastic RSI K 64.7532557339602
# stochastic %K(14, 3, 3) 65.5419124217194

# %%
def check_signal(df):
    last = df.iloc[-1]

    rsi = last["rsi"]
    stoch_rsi = last["stoch_rsi_k"]   # stochastic(14,14,3,3)
    stoch_k = last["stoch_d"]         # stochastic %K(14,3,3)

    # === Condition 1: Oversold ===
    oversold = (
        rsi < 45 and
        stoch_rsi < 45 and
        stoch_k < 45
    )

    # === Condition 2: Momentum shift ===
    momentum = stoch_k > stoch_rsi

    return oversold and momentum

# %%
timeframes = ['15m', '1h', '4h', '1d']

def analyze_symbol(symbol):
    agreeing_timeframes = []

    for tf in timeframes:
        try:
            df = get_ohlcv(symbol, tf, 500)

            df = df.iloc[:-1]  # remove live candle

            df = add_rsi_tradingview(df)
            df = add_stochastic_tv(df, 14, 3, 3)
            df = add_stoch_rsi_tv(df, 14, 14, 3, 3)

            if check_signal(df):
                agreeing_timeframes.append(tf)

        except Exception as e:
            print(f"Error {symbol} {tf}: {e}")

    return agreeing_timeframes

# %%
def scan_market(pairs):
    results = {}

    for i, symbol in enumerate(pairs, 1):
        print(f"[{i}/{len(pairs)}] Scanning {symbol}...")

        agreeing = analyze_symbol(symbol)

        if len(agreeing) >= 2:
            results[symbol] = agreeing
            print(f"🚀 SIGNAL FOUND: {symbol} → {agreeing}")

    return results

# %%
signals = scan_market(filtered_pairs)
# Out:
# [1/439] Scanning BTC/USDT...
# [2/439] Scanning ETH/USDT...
# [3/439] Scanning BNB/USDT...
# [4/439] Scanning NEO/USDT...
# [5/439] Scanning LTC/USDT...
# [6/439] Scanning QTUM/USDT...
# [7/439] Scanning ADA/USDT...
# [8/439] Scanning XRP/USDT...
# [9/439] Scanning TUSD/USDT...
# [10/439] Scanning IOTA/USDT...
# [11/439] Scanning XLM/USDT...
# [12/439] Scanning ONT/USDT...
# 🚀 SIGNAL FOUND: ONT/USDT → ['15m', '1h']
# [13/439] Scanning TRX/USDT...
# [14/439] Scanning ETC/USDT...
# [15/439] Scanning ICX/USDT...
# [16/439] Scanning VET/USDT...
# [17/439] Scanning USDC/USDT...
# [18/439] Scanning LINK/USDT...
# [19/439] Scanning ONG/USDT...
# [20/439] Scanning HOT/USDT...
# [21/439] Scanning ZIL/USDT...
# [22/439] Scanning ZRX/USDT...
# [23/439] Scanning FET/USDT...
# [24/439] Scanning BAT/USDT...
# 🚀 SIGNAL FOUND: BAT/USDT → ['15m', '1h']
# [25/439] Scanning ZEC/USDT...
# 🚀 SIGNAL FOUND: ZEC/USDT → ['15m', '1h']
    print(f"{pair} → {tfs}")
# Out:
# === FINAL SIGNALS ===
# ONT/USDT → ['15m', '1h']
# BAT/USDT → ['15m', '1h']
# ZEC/USDT → ['15m', '1h']
# CELR/USDT → ['1h', '4h']
# DASH/USDT → ['15m', '1h', '4h']
# ENJ/USDT → ['15m', '4h']
# COS/USDT → ['15m', '1h']
# CHZ/USDT → ['15m', '1h', '4h']
# STX/USDT → ['15m', '1d']
# IOTX/USDT → ['15m', '4h']
# RLC/USDT → ['15m', '1h']
# BCH/USDT → ['15m', '1h']
# EUR/USDT → ['4h', '1d']
# MBL/USDT → ['15m', '4h']
# CTSI/USDT → ['15m', '1d']
# CHR/USDT → ['15m', '1h']
# MDT/USDT → ['15m', '1d']
# YFI/USDT → ['15m', '1h', '4h']
# LUNA/USDT → ['15m', '1h']
# UTK/USDT → ['15m', '4h']
# AVA/USDT → ['15m', '1h']
# DEGO/USDT → ['15m', '1h']
# PUNDIX/USDT → ['15m', '1h']
# LPT/USDT → ['1h', '4h']
# C98/USDT → ['15m', '1h', '4h']
# QNT/USDT → ['15m', '4h']
# WAXP/USDT → ['15m', '1h']
# DYDX/USDT → ['15m', '1h']
# FLUX/USDT → ['15m', '1h']
# CVX/USDT → ['1h', '4h']
# ACH/USDT → ['15m', '1h', '4h']
# XNO/USDT → ['1h', '4h', '1d']
# GMT/USDT → ['15m', '1h']
# APE/USDT → ['15m', '1d']
# STEEM/USDT → ['15m', '4h']
# HFT/USDT → ['15m', '1h']
# PHB/USDT → ['15m', '1h']
# MAGIC/USDT → ['15m', '1h']
# SSV/USDT → ['15m', '1h', '4h']
# EDU/USDT → ['15m', '1d']
# PEPE/USDT → ['15m', '1h', '4h']
# MAV/USDT → ['15m', '4h']
# ORDI/USDT → ['15m', '4h']
# PIVX/USDT → ['15m', '4h']
# NFP/USDT → ['15m', '1h']
# MANTA/USDT → ['15m', '1h']
# DYM/USDT → ['15m', '4h']
# PORTAL/USDT → ['15m', '1h']
# ENA/USDT → ['15m', '1h']
# ZK/USDT → ['15m', '1d']
# LISTA/USDT → ['15m', '1h']
# TON/USDT → ['15m', '1h', '4h']
# EURI/USDT → ['4h', '1d']
# SCR/USDT → ['15m', '1h']
# KAIA/USDT → ['15m', '1h']
# CGPT/USDT → ['15m', '1h']
# ANIME/USDT → ['15m', '1d']
# SHELL/USDT → ['15m', '1h']
# RED/USDT → ['15m', '1d']
# BMT/USDT → ['15m', '1h']
# FORM/USDT → ['15m', '1h']
# BABY/USDT → ['15m', '4h']
# HUMA/USDT → ['15m', '1h', '4h']
# A2Z/USDT → ['15m', '1h']
# TOWNS/USDT → ['15m', '1h']
# OPEN/USDT → ['15m', '1d']
# SKY/USDT → ['1h', '4h']
# ASTER/USDT → ['15m', '1h']
# GIGGLE/USDT → ['15m', '1h', '4h']
# MMT/USDT → ['15m', '1h']
# SAPIEN/USDT → ['15m', '1h']
# BANK/USDT → ['1h', '4h']
# KGST/USDT → ['15m', '1h']
# RLUSD/USDT → ['15m', '1h']
