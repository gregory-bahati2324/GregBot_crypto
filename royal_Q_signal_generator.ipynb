# %%
import ccxt
import pandas as pd
import ta

# %%
exchange = ccxt.binance({
    'enableRateLimit': True,  # important to avoid ban
})

# %%
markets = exchange.load_markets()

# %%
usdt_pairs = []

for symbol, market in markets.items():
    if (
        symbol.endswith('/USDT') and
        market['spot'] and
        market['active']
    ):
        usdt_pairs.append(symbol)

print(f"Total active USDT spot pairs: {len(usdt_pairs)}")
print(usdt_pairs[:10])  # show first 10
# Out:
# Total active USDT spot pairs: 441
# ['BTC/USDT', 'ETH/USDT', 'BNB/USDT', 'NEO/USDT', 'LTC/USDT', 'QTUM/USDT', 'ADA/USDT', 'XRP/USDT', 'TUSD/USDT', 'IOTA/USDT']

# %%
filtered_pairs = [
    symbol for symbol in usdt_pairs
    if not any(x in symbol for x in ['UP/', 'DOWN/', 'BULL/', 'BEAR/'])
]

print(f"Clean USDT pairs: {len(filtered_pairs)}")
# Out:
# Clean USDT pairs: 439

# %%
def get_ohlcv(symbol, timeframe='15m', limit=200):
    ohlcv = exchange.fetch_ohlcv(symbol, timeframe=timeframe, limit=limit)
    
    df = pd.DataFrame(ohlcv, columns=[
        'timestamp','open','high','low','close','volume'
    ])
    
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    return df

# %%
import pandas as pd
import numpy as np

def add_rsi_tradingview(df, length=14, source_col='close'):
    """
    TradingView / Pine Script RSI implementation using RMA (Wilder)
    """

    # 1. Price change (ta.change)
    change = df[source_col].diff()

    # 2. Up & Down series
    up = change.clip(lower=0)
    down = -change.clip(upper=0)

    # 3. Wilder's Moving Average (RMA)
    alpha = 1 / length
    avg_up = up.ewm(alpha=alpha, adjust=False).mean()
    avg_down = down.ewm(alpha=alpha, adjust=False).mean()

    # 4. RSI calculation
    rs = avg_up / avg_down
    rsi = np.where(
        avg_down == 0, 100,
        np.where(avg_up == 0, 0, 100 - (100 / (1 + rs)))
    )

    df['rsi'] = rsi
    return df

# %%
def add_stochastic_tv(df, periodK=14, smoothK=3, periodD=3):
    
    # Raw stochastic
    low_min = df['low'].rolling(periodK).min()
    high_max = df['high'].rolling(periodK).max()
    
    stoch = 100 * (df['close'] - low_min) / (high_max - low_min)
    
    # Smooth K
    k = stoch.rolling(smoothK).mean()
    
    # Smooth D
    d = k.rolling(periodD).mean()
    
    df['stoch_k'] = k
    df['stoch_d'] = d
    
    return df

# %%
def add_stoch_rsi_tv(df, lengthRSI=14, lengthStoch=14, smoothK=3, smoothD=3):

    # --- TRUE TradingView RSI (RMA based)
    delta = df['close'].diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)

    alpha = 1 / lengthRSI
    avg_gain = gain.ewm(alpha=alpha, adjust=False).mean()
    avg_loss = loss.ewm(alpha=alpha, adjust=False).mean()

    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))

    # --- TRUE Stochastic of RSI
    rsi_min = rsi.rolling(lengthStoch).min()
    rsi_max = rsi.rolling(lengthStoch).max()

    stoch = 100 * (rsi - rsi_min) / (rsi_max - rsi_min)

    # --- Smooth K and D
    k = stoch.rolling(smoothK).mean()
    d = k.rolling(smoothD).mean()

    df['stoch_rsi_k'] = k
    df['stoch_rsi_d'] = d

    return df

# %%
df = get_ohlcv('ADA/USDT', '1d', 200)
df = add_rsi_tradingview(df)
df = add_stochastic_tv(df)
df = add_stoch_rsi_tv(df, 14, 14, 3, 3)

# %%
last = df.iloc[-1]

print("Symbol: ADA/USDT")
print("RSI:", last['rsi'])
print("stochastic RSI K", last['stoch_rsi_k']) #Required for stochastic(14, 14, 3, 3) strategy
print("stochastic %K(14, 3, 3)", last['stoch_d']) # required for stochastic%K(14,3, 3) strategy
# Out:
# Symbol: ADA/USDT
# RSI: 35.00539446246863
# stochastic RSI K 82.35689789596684
# stochastic %K(14, 3, 3) 31.887721163517202

# %%
def check_signal(df):
    last = df.iloc[-1]

    rsi = last["rsi"]
    stoch_rsi = last["stoch_rsi_k"]   # stochastic(14,14,3,3)
    stoch_k = last["stoch_d"]         # stochastic %K(14,3,3)

    # === Condition 1: Oversold ===
    oversold = (
        rsi < 45 and
        stoch_rsi < 45 and
        stoch_k < 45
    )

    # === Condition 2: Momentum shift ===
    momentum = stoch_k > stoch_rsi

    return oversold and momentum

# %%
timeframes = ['15m', '1h', '4h', '1d']

def analyze_symbol(symbol):
    agreeing_timeframes = []

    for tf in timeframes:
        try:
            df = get_ohlcv(symbol, tf, 500)

            df = df.iloc[:-1]  # remove live candle

            df = add_rsi_tradingview(df)
            df = add_stochastic_tv(df, 14, 3, 3)
            df = add_stoch_rsi_tv(df, 14, 14, 3, 3)

            if check_signal(df):
                agreeing_timeframes.append(tf)

        except Exception as e:
            print(f"Error {symbol} {tf}: {e}")

    return agreeing_timeframes

# %%
def scan_market(pairs):
    results = {}

    for symbol in pairs:
        print(f"Scanning {symbol}...")
        agreeing = analyze_symbol(symbol)

        if len(agreeing) >= 2:  # require at least 2 TFs agreement
            results[symbol] = agreeing

    return results

# %%
signals = scan_market(filtered_pairs)

print("\n=== FINAL SIGNALS ===")
for pair, tfs in signals.items():
    print(f"{pair} → {tfs}")
# Out:
# Scanning BTC/USDT...
# Scanning ETH/USDT...
# Scanning BNB/USDT...
# Scanning NEO/USDT...
# Scanning LTC/USDT...
# Scanning QTUM/USDT...
# Scanning ADA/USDT...
# Scanning XRP/USDT...
# Scanning TUSD/USDT...
# Scanning IOTA/USDT...
# Scanning XLM/USDT...
# Scanning ONT/USDT...
# Scanning TRX/USDT...
# Scanning ETC/USDT...
# Scanning ICX/USDT...
# Scanning VET/USDT...
# Scanning USDC/USDT...
# Scanning LINK/USDT...
# Scanning ONG/USDT...
# Scanning HOT/USDT...
# Scanning ZIL/USDT...
# Scanning ZRX/USDT...
# Scanning FET/USDT...
# Scanning BAT/USDT...
# Scanning ZEC/USDT...
# Scanning IOST/USDT...
# Scanning CELR/USDT...
# Scanning DASH/USDT...
# Scanning THETA/USDT...
# Scanning ENJ/USDT...
# Scanning ATOM/USDT...
# Scanning TFUEL/USDT...
# Scanning ONE/USDT...
# Scanning ALGO/USDT...
# Scanning DOGE/USDT...
# Scanning DUSK/USDT...
# Scanning ANKR/USDT...
# Scanning WIN/USDT...
# Scanning COS/USDT...
# Scanning MTL/USDT...
# Scanning DENT/USDT...
# Scanning WAN/USDT...
# Scanning FUN/USDT...
# Scanning CVC/USDT...
# Scanning CHZ/USDT...
# Scanning BAND/USDT...
# Scanning XTZ/USDT...
# Scanning RVN/USDT...
# Scanning HBAR/USDT...
# Scanning STX/USDT...
# Scanning KAVA/USDT...
# Scanning ARPA/USDT...
# Scanning IOTX/USDT...
# Scanning RLC/USDT...
# Scanning BCH/USDT...
# Scanning FTT/USDT...
# Scanning EUR/USDT...
# Scanning OGN/USDT...
# Scanning LSK/USDT...
# Scanning BNT/USDT...
# Scanning MBL/USDT...
# Scanning COTI/USDT...
# Scanning SOL/USDT...
# Scanning CTSI/USDT...
# Scanning HIVE/USDT...
# Scanning CHR/USDT...
# Scanning ARDR/USDT...
# Scanning MDT/USDT...
# Scanning KNC/USDT...
# Scanning LRC/USDT...
# Scanning COMP/USDT...
# Scanning SC/USDT...
# Scanning ZEN/USDT...
# Scanning SNX/USDT...
# Scanning VTHO/USDT...
# Scanning DGB/USDT...
# Scanning SXP/USDT...
# Scanning DCR/USDT...
# Scanning STORJ/USDT...
# Scanning MANA/USDT...
# Scanning YFI/USDT...
# Scanning JST/USDT...
# Scanning CRV/USDT...
# Scanning SAND/USDT...
# Scanning NMR/USDT...
# Scanning DOT/USDT...
# Scanning LUNA/USDT...
# Scanning RSR/USDT...
# Scanning PAXG/USDT...
# Scanning TRB/USDT...
# Scanning SUSHI/USDT...
# Scanning KSM/USDT...
# Scanning EGLD/USDT...
# Scanning DIA/USDT...
# Scanning RUNE/USDT...
# Scanning FIO/USDT...
# Scanning UMA/USDT...
# Scanning BEL/USDT...
# Scanning UNI/USDT...
# Scanning OXT/USDT...
# Scanning SUN/USDT...
# Scanning AVAX/USDT...
# Scanning UTK/USDT...
# Scanning XVS/USDT...
# Scanning AAVE/USDT...
# Scanning NEAR/USDT...
# Scanning FIL/USDT...
# Scanning INJ/USDT...
# Scanning AUDIO/USDT...
# Scanning CTK/USDT...
# Scanning AXS/USDT...
# Scanning STRAX/USDT...
# Scanning ROSE/USDT...
# Scanning AVA/USDT...
# Scanning SKL/USDT...
# Scanning GRT/USDT...
# Scanning JUV/USDT...
# Scanning PSG/USDT...
# Scanning 1INCH/USDT...
# Scanning OG/USDT...
# Scanning ATM/USDT...
# Scanning ASR/USDT...
# Scanning CELO/USDT...
# Scanning RIF/USDT...
# Scanning TRU/USDT...
# Scanning CKB/USDT...
# Scanning TWT/USDT...
# Scanning SFP/USDT...
# Scanning DODO/USDT...
# Scanning CAKE/USDT...
# Scanning ACM/USDT...
# Scanning OM/USDT...
# Scanning POND/USDT...
# Scanning DEGO/USDT...
# Scanning ALICE/USDT...
# Scanning SUPER/USDT...
# Scanning CFX/USDT...
# Scanning TKO/USDT...
# Scanning PUNDIX/USDT...
# Scanning TLM/USDT...
# Scanning BAR/USDT...
# Scanning FORTH/USDT...
# Scanning SLP/USDT...
# Scanning SHIB/USDT...
# Scanning ICP/USDT...
# Scanning AR/USDT...
# Scanning MASK/USDT...
# Scanning LPT/USDT...
# Scanning XVG/USDT...
# Scanning ATA/USDT...
# Scanning GTC/USDT...
# Scanning PHA/USDT...
# Scanning MLN/USDT...
# Scanning DEXE/USDT...
# Scanning C98/USDT...
# Scanning QNT/USDT...
# Scanning FLOW/USDT...
# Scanning MINA/USDT...
# Scanning RAY/USDT...
# Scanning FARM/USDT...
# Scanning QUICK/USDT...
# Scanning MBOX/USDT...
# Scanning REQ/USDT...
# Scanning WAXP/USDT...
# Scanning GNO/USDT...
# Scanning XEC/USDT...
# Scanning DYDX/USDT...
# Scanning IDEX/USDT...
# Scanning USDP/USDT...
# Scanning GALA/USDT...
# Scanning ILV/USDT...
# Scanning YGG/USDT...
# Scanning SYS/USDT...
# Scanning FIDA/USDT...
# Scanning AGLD/USDT...
# Scanning RAD/USDT...
# Scanning RARE/USDT...
# Scanning LAZIO/USDT...
# Scanning ADX/USDT...
# Scanning AUCTION/USDT...
# Scanning MOVR/USDT...
# Scanning CITY/USDT...
# Scanning ENS/USDT...
# Scanning QI/USDT...
# Scanning PORTO/USDT...
# Scanning POWR/USDT...
# Scanning JASMY/USDT...
# Scanning AMP/USDT...
# Scanning PYR/USDT...
# Scanning ALCX/USDT...
# Scanning SANTOS/USDT...
# Scanning BICO/USDT...
# Scanning FLUX/USDT...
# Scanning HIGH/USDT...
# Scanning CVX/USDT...
# Scanning PEOPLE/USDT...
# Scanning SPELL/USDT...
# Scanning JOE/USDT...
# Scanning ACH/USDT...
# Scanning IMX/USDT...
# Scanning GLMR/USDT...
# Scanning SCRT/USDT...
# Scanning API3/USDT...
# Scanning BTTC/USDT...
# Scanning XNO/USDT...
# Scanning WOO/USDT...
# Scanning ALPINE/USDT...
# Scanning T/USDT...
# Scanning ASTR/USDT...
# Scanning GMT/USDT...
# Scanning APE/USDT...
# Scanning BIFI/USDT...
# Scanning STEEM/USDT...
# Scanning NEXO/USDT...
# Scanning LDO/USDT...
# Scanning OP/USDT...
# Scanning STG/USDT...
# Scanning LUNC/USDT...
# Scanning GMX/USDT...
# Scanning POLYX/USDT...
# Scanning APT/USDT...
# Scanning OSMO/USDT...
# Scanning HFT/USDT...
# Scanning PHB/USDT...
# Scanning HOOK/USDT...
# Scanning MAGIC/USDT...
# Scanning RPL/USDT...
# Scanning GNS/USDT...
# Scanning SYN/USDT...
# Scanning SSV/USDT...
# Scanning LQTY/USDT...
# Scanning USTC/USDT...
# Scanning GAS/USDT...
# Scanning GLM/USDT...
# Scanning PROM/USDT...
# Scanning QKC/USDT...
# Scanning ID/USDT...
# Scanning ARB/USDT...
# Scanning RDNT/USDT...
# Scanning WBTC/USDT...
# Scanning EDU/USDT...
# Scanning SUI/USDT...
# Scanning PEPE/USDT...
# Scanning FLOKI/USDT...
# Scanning MAV/USDT...
# Scanning PENDLE/USDT...
# Scanning ARKM/USDT...
# Scanning WBETH/USDT...
# Scanning WLD/USDT...
# Scanning FDUSD/USDT...
# Scanning SEI/USDT...
# Scanning CYBER/USDT...
# Scanning ARK/USDT...
# Scanning IQ/USDT...
# Scanning NTRN/USDT...
# Scanning TIA/USDT...
# Scanning MEME/USDT...
# Scanning ORDI/USDT...
# Scanning BEAMX/USDT...
# Scanning PIVX/USDT...
# Scanning VIC/USDT...
# Scanning BLUR/USDT...
# Scanning VANRY/USDT...
# Scanning AEUR/USDT...
# Scanning JTO/USDT...
# Scanning 1000SATS/USDT...
# Scanning BONK/USDT...
# Scanning ACE/USDT...
# Scanning NFP/USDT...
# Scanning AI/USDT...
# Scanning XAI/USDT...
# Scanning MANTA/USDT...
# Scanning ALT/USDT...
# Scanning PYTH/USDT...
# Scanning RONIN/USDT...
# Scanning DYM/USDT...
# Scanning PIXEL/USDT...
# Scanning STRK/USDT...
# Scanning PORTAL/USDT...
# Scanning AXL/USDT...
# Scanning WIF/USDT...
# Scanning METIS/USDT...
# Scanning AEVO/USDT...
# Scanning BOME/USDT...
# Scanning ETHFI/USDT...
# Scanning ENA/USDT...
# Scanning W/USDT...
# Scanning TNSR/USDT...
# Scanning SAGA/USDT...
# Scanning TAO/USDT...
# Scanning REZ/USDT...
# Scanning BB/USDT...
# Scanning NOT/USDT...
# Scanning IO/USDT...
# Error IO/USDT 15m: binance GET https://api.binance.com/api/v3/klines?interval=15m&limit=500&symbol=IOUSDT
# Scanning ZK/USDT...
# Scanning LISTA/USDT...
# Scanning ZRO/USDT...
# Scanning G/USDT...
# Scanning BANANA/USDT...
# Scanning RENDER/USDT...
# Scanning TON/USDT...
# Scanning DOGS/USDT...
# Scanning EURI/USDT...
# Scanning POL/USDT...
# Scanning NEIRO/USDT...
# Scanning TURBO/USDT...
# Scanning 1MBABYDOGE/USDT...
# Scanning CATI/USDT...
# Scanning HMSTR/USDT...
# Scanning EIGEN/USDT...
# Scanning SCR/USDT...
# Scanning BNSOL/USDT...
# Scanning LUMIA/USDT...
# Scanning KAIA/USDT...
# Scanning COW/USDT...
# Scanning CETUS/USDT...
# Scanning PNUT/USDT...
# Scanning ACT/USDT...
# Scanning USUAL/USDT...
# Scanning THE/USDT...
# Scanning ACX/USDT...
# Scanning ORCA/USDT...
# Scanning MOVE/USDT...
# Scanning ME/USDT...
# Scanning VELODROME/USDT...
# Scanning VANA/USDT...
# Scanning 1000CAT/USDT...
# Scanning PENGU/USDT...
# Scanning BIO/USDT...
# Scanning D/USDT...
# Scanning AIXBT/USDT...
# Scanning CGPT/USDT...
# Scanning COOKIE/USDT...
# Scanning S/USDT...
# Scanning SOLV/USDT...
# Scanning TRUMP/USDT...
# Scanning ANIME/USDT...
# Scanning BERA/USDT...
# Scanning 1000CHEEMS/USDT...
# Scanning TST/USDT...
# Scanning LAYER/USDT...
# Scanning HEI/USDT...
# Scanning KAITO/USDT...
# Scanning SHELL/USDT...
# Scanning RED/USDT...
# Scanning GPS/USDT...
# Scanning EPIC/USDT...
# Scanning BMT/USDT...
# Scanning FORM/USDT...
# Scanning XUSD/USDT...
# Scanning NIL/USDT...
# Scanning PARTI/USDT...
# Scanning MUBARAK/USDT...
# Scanning TUT/USDT...
# Scanning BROCCOLI714/USDT...
# Scanning BANANAS31/USDT...
# Scanning GUN/USDT...
# Scanning BABY/USDT...
# Scanning ONDO/USDT...
# Scanning BIGTIME/USDT...
# Scanning VIRTUAL/USDT...
# Scanning KERNEL/USDT...
# Scanning WCT/USDT...
# Scanning HYPER/USDT...
# Scanning INIT/USDT...
# Scanning SIGN/USDT...
# Scanning STO/USDT...
# Scanning KMNO/USDT...
# Scanning SXT/USDT...
# Scanning NXPC/USDT...
# Scanning AWE/USDT...
# Scanning HAEDAL/USDT...
# Scanning USD1/USDT...
# Scanning HUMA/USDT...
# Scanning A/USDT...
# Scanning SOPH/USDT...
# Scanning RESOLV/USDT...
# Scanning HOME/USDT...
# Scanning SPK/USDT...
# Scanning NEWT/USDT...
# Scanning SAHARA/USDT...
# Scanning LA/USDT...
# Scanning ERA/USDT...
# Scanning C/USDT...
# Scanning TREE/USDT...
# Scanning A2Z/USDT...
# Scanning TOWNS/USDT...
# Error TOWNS/USDT 15m: binance GET https://api.binance.com/api/v3/klines?interval=15m&limit=500&symbol=TOWNSUSDT
# Scanning PROVE/USDT...
# Scanning BFUSD/USDT...
# Scanning PLUME/USDT...
# Scanning DOLO/USDT...
# Error DOLO/USDT 4h: binance GET https://api.binance.com/api/v3/klines?interval=4h&limit=500&symbol=DOLOUSDT
# Scanning MITO/USDT...
# Scanning WLFI/USDT...
# Scanning SOMI/USDT...
# Scanning OPEN/USDT...
# Scanning USDE/USDT...
# Scanning LINEA/USDT...
# Scanning HOLO/USDT...
# Scanning PUMP/USDT...
# Scanning AVNT/USDT...
# Scanning ZKC/USDT...
# Scanning SKY/USDT...
# Scanning BARD/USDT...
# Scanning 0G/USDT...
# Error 0G/USDT 15m: binance GET https://api.binance.com/api/v3/klines?interval=15m&limit=500&symbol=0GUSDT
# Scanning HEMI/USDT...
# Scanning XPL/USDT...
# Scanning MIRA/USDT...
# Scanning FF/USDT...
# Scanning EDEN/USDT...
# Scanning NOM/USDT...
# Scanning 2Z/USDT...
# Scanning MORPHO/USDT...
# Scanning ASTER/USDT...
# Scanning WAL/USDT...
# Scanning EUL/USDT...
# Scanning ENSO/USDT...
# Scanning YB/USDT...
# Scanning ZBT/USDT...
# Scanning TURTLE/USDT...
# Scanning GIGGLE/USDT...
# Scanning F/USDT...
# Scanning KITE/USDT...
# Scanning MMT/USDT...
# Scanning SAPIEN/USDT...
# Scanning ALLO/USDT...
# Scanning BANK/USDT...
# Scanning MET/USDT...
# Scanning AT/USDT...
# Scanning KGST/USDT...
# Scanning BREV/USDT...
# Scanning 币安人生/USDT...
# Scanning ZKP/USDT...
# Scanning U/USDT...
# Scanning FRAX/USDT...
# Scanning FOGO/USDT...
# Scanning RLUSD/USDT...
# Scanning SENT/USDT...
# Scanning ZAMA/USDT...
# Scanning ESP/USDT...
#
# === FINAL SIGNALS ===
# BNB/USDT → ['15m', '1h']
# ROSE/USDT → ['4h', '1d']
# RIF/USDT → ['15m', '4h']
# CAKE/USDT → ['1h', '4h']
# BICO/USDT → ['15m', '1h']
# GUN/USDT → ['1h', '4h']
# HEMI/USDT → ['1h', '4h']

# %%
print("\n=== FINAL SIGNALS ===")
for pair, tfs in signals.items():
    print(f"{pair} → {tfs}")
# Out:
# === FINAL SIGNALS ===
# BNB/USDT → ['15m', '1h']
# ROSE/USDT → ['4h', '1d']
# RIF/USDT → ['15m', '4h']
# CAKE/USDT → ['1h', '4h']
# BICO/USDT → ['15m', '1h']
# GUN/USDT → ['1h', '4h']
# HEMI/USDT → ['1h', '4h']
