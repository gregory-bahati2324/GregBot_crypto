# %%
import ccxt
import pandas as pd
import numpy as np
import ta

exchange = ccxt.binance({
    "enableRateLimit": True,
    "options": {
        "defaultType": "future"   # ← THIS switches to futures
    }
})

# %%
markets = exchange.load_markets()

usdt_pairs = [
    symbol for symbol, market in markets.items()
    if market['quote'] == 'USDT'     # Must be USDT pair
    and market['contract']           # Must be derivative
    and market['swap']               # Must be perpetual (not quarterly)
    and market['active']             # Must be active
]

print(f"Total active USDT futures pairs: {len(usdt_pairs)}")
print(usdt_pairs[:10])
# Out:
# Total active USDT futures pairs: 553
# ['BTC/USDT:USDT', 'ETH/USDT:USDT', 'BCH/USDT:USDT', 'XRP/USDT:USDT', 'LTC/USDT:USDT', 'TRX/USDT:USDT', 'ETC/USDT:USDT', 'LINK/USDT:USDT', 'XLM/USDT:USDT', 'ADA/USDT:USDT']

# %%
filtered_pairs = []

for symbol in usdt_pairs:
    print(f"scan {symbol}")
    ticker = exchange.fetch_ticker(symbol)

    if ticker['quoteVolume'] and ticker['quoteVolume'] > 5_000_000:
        filtered_pairs.append(symbol)

print(f"High-liquidity USDT futures: {len(filtered_pairs)}")
# Out:
# scan BTC/USDT:USDT
# scan ETH/USDT:USDT
# scan BCH/USDT:USDT
# scan XRP/USDT:USDT
# scan LTC/USDT:USDT
# scan TRX/USDT:USDT
# scan ETC/USDT:USDT
# scan LINK/USDT:USDT
# scan XLM/USDT:USDT
# scan ADA/USDT:USDT
# scan XMR/USDT:USDT
# scan DASH/USDT:USDT
# scan ZEC/USDT:USDT
# scan XTZ/USDT:USDT
# scan BNB/USDT:USDT
# scan ATOM/USDT:USDT
# scan ONT/USDT:USDT
# scan IOTA/USDT:USDT
# scan BAT/USDT:USDT
# scan VET/USDT:USDT
# scan NEO/USDT:USDT
# scan QTUM/USDT:USDT
# scan IOST/USDT:USDT
# scan THETA/USDT:USDT
# scan ALGO/USDT:USDT
# scan ZIL/USDT:USDT
# scan KNC/USDT:USDT
# scan ZRX/USDT:USDT
# scan COMP/USDT:USDT
# scan DOGE/USDT:USDT
# scan KAVA/USDT:USDT
# scan BAND/USDT:USDT
# scan RLC/USDT:USDT
# scan SNX/USDT:USDT
# scan DOT/USDT:USDT
# scan YFI/USDT:USDT
# scan CRV/USDT:USDT
# scan TRB/USDT:USDT
# scan RUNE/USDT:USDT
# scan SUSHI/USDT:USDT
# scan EGLD/USDT:USDT
# scan SOL/USDT:USDT
# scan ICX/USDT:USDT
# scan STORJ/USDT:USDT
# scan UNI/USDT:USDT
# scan AVAX/USDT:USDT
# scan ENJ/USDT:USDT
# scan KSM/USDT:USDT
# scan NEAR/USDT:USDT
# scan AAVE/USDT:USDT
# scan FIL/USDT:USDT
# scan RSR/USDT:USDT
# scan LRC/USDT:USDT
# scan BEL/USDT:USDT
# scan AXS/USDT:USDT
# scan ZEN/USDT:USDT
# scan SKL/USDT:USDT
# scan GRT/USDT:USDT
# scan 1INCH/USDT:USDT
# scan CHZ/USDT:USDT
# scan SAND/USDT:USDT
# scan ANKR/USDT:USDT
# scan RVN/USDT:USDT
# scan SFP/USDT:USDT
# scan COTI/USDT:USDT
# scan CHR/USDT:USDT
# scan MANA/USDT:USDT
# scan ALICE/USDT:USDT
# scan HBAR/USDT:USDT
# scan ONE/USDT:USDT
# scan DENT/USDT:USDT
# scan CELR/USDT:USDT
# scan HOT/USDT:USDT
# scan MTL/USDT:USDT
# scan OGN/USDT:USDT
# scan 1000SHIB/USDT:USDT
# scan GTC/USDT:USDT
# scan BTCDOM/USDT:USDT
# scan IOTX/USDT:USDT
# scan C98/USDT:USDT
# scan MASK/USDT:USDT
# scan ATA/USDT:USDT
# scan DYDX/USDT:USDT
# scan 1000XEC/USDT:USDT
# scan GALA/USDT:USDT
# scan CELO/USDT:USDT
# scan AR/USDT:USDT
# scan ARPA/USDT:USDT
# scan CTSI/USDT:USDT
# scan LPT/USDT:USDT
# scan ENS/USDT:USDT
# scan PEOPLE/USDT:USDT
# scan ROSE/USDT:USDT
# scan DUSK/USDT:USDT
# scan FLOW/USDT:USDT
# scan IMX/USDT:USDT
# scan API3/USDT:USDT
# scan GMT/USDT:USDT
# scan APE/USDT:USDT
# scan WOO/USDT:USDT
# scan JASMY/USDT:USDT
# scan OP/USDT:USDT
# scan INJ/USDT:USDT
# scan STG/USDT:USDT
# scan SPELL/USDT:USDT
# scan 1000LUNC/USDT:USDT
# scan LUNA2/USDT:USDT
# scan LDO/USDT:USDT
# scan ICP/USDT:USDT
# scan APT/USDT:USDT
# scan QNT/USDT:USDT
# scan FET/USDT:USDT
# scan HOOK/USDT:USDT
# scan MAGIC/USDT:USDT
# scan T/USDT:USDT
# scan HIGH/USDT:USDT
# scan MINA/USDT:USDT
# scan ASTR/USDT:USDT
# scan PHB/USDT:USDT
# scan GMX/USDT:USDT
# scan CFX/USDT:USDT
# scan STX/USDT:USDT
# scan ACH/USDT:USDT
# scan SSV/USDT:USDT
# scan CKB/USDT:USDT
# scan TRU/USDT:USDT
# scan LQTY/USDT:USDT
# scan USDC/USDT:USDT
# scan ID/USDT:USDT
# scan ARB/USDT:USDT
# scan JOE/USDT:USDT
# scan TLM/USDT:USDT
# scan RDNT/USDT:USDT
# scan HFT/USDT:USDT
# scan XVS/USDT:USDT
# scan BLUR/USDT:USDT
# scan EDU/USDT:USDT
# scan SUI/USDT:USDT
# scan 1000PEPE/USDT:USDT
# scan 1000FLOKI/USDT:USDT
# scan UMA/USDT:USDT
# scan NMR/USDT:USDT
# scan MAV/USDT:USDT
# scan XVG/USDT:USDT
# scan WLD/USDT:USDT
# scan PENDLE/USDT:USDT
# scan ARKM/USDT:USDT
# scan AGLD/USDT:USDT
# scan YGG/USDT:USDT
# scan DODOX/USDT:USDT
# scan BNT/USDT:USDT
# scan OXT/USDT:USDT
# scan SEI/USDT:USDT
# scan CYBER/USDT:USDT
# scan ARK/USDT:USDT
# scan BICO/USDT:USDT
# scan BIGTIME/USDT:USDT
# scan WAXP/USDT:USDT
# scan BSV/USDT:USDT
# scan RIF/USDT:USDT
# scan POLYX/USDT:USDT
# scan GAS/USDT:USDT
# scan POWR/USDT:USDT
# scan TIA/USDT:USDT
# scan CAKE/USDT:USDT
# scan MEME/USDT:USDT
# scan TWT/USDT:USDT
# scan ORDI/USDT:USDT
# scan STEEM/USDT:USDT
# scan ILV/USDT:USDT
# scan NTRN/USDT:USDT
# scan KAS/USDT:USDT
# scan BEAMX/USDT:USDT
# scan 1000BONK/USDT:USDT
# scan PYTH/USDT:USDT
# scan SUPER/USDT:USDT
# scan USTC/USDT:USDT
# scan ONG/USDT:USDT
# scan ETHW/USDT:USDT
# scan JTO/USDT:USDT
# scan 1000SATS/USDT:USDT
# scan AUCTION/USDT:USDT
# scan 1000RATS/USDT:USDT
# scan ACE/USDT:USDT
# scan MOVR/USDT:USDT
# scan NFP/USDT:USDT
# scan AI/USDT:USDT
# scan XAI/USDT:USDT
# scan WIF/USDT:USDT
# scan MANTA/USDT:USDT
# scan ONDO/USDT:USDT
# scan LSK/USDT:USDT
# scan ALT/USDT:USDT
# scan JUP/USDT:USDT
# scan ZETA/USDT:USDT
# scan RONIN/USDT:USDT
# scan DYM/USDT:USDT
# scan PIXEL/USDT:USDT
# scan STRK/USDT:USDT
# scan GLM/USDT:USDT
# scan PORTAL/USDT:USDT
# scan TON/USDT:USDT
# scan AXL/USDT:USDT
# scan METIS/USDT:USDT
# scan AEVO/USDT:USDT
# scan VANRY/USDT:USDT
# scan BOME/USDT:USDT
# scan ETHFI/USDT:USDT
# scan ENA/USDT:USDT
# scan W/USDT:USDT
# scan TNSR/USDT:USDT
# scan SAGA/USDT:USDT
# scan TAO/USDT:USDT
# scan REZ/USDT:USDT
# scan BB/USDT:USDT
# scan NOT/USDT:USDT
# scan TURBO/USDT:USDT
# scan IO/USDT:USDT
# scan ZK/USDT:USDT
# scan MEW/USDT:USDT
# scan LISTA/USDT:USDT
# scan ZRO/USDT:USDT
# scan RENDER/USDT:USDT
# scan BANANA/USDT:USDT
# scan RARE/USDT:USDT
# scan G/USDT:USDT
# scan SYN/USDT:USDT
# scan SYS/USDT:USDT
# scan BRETT/USDT:USDT
# scan POPCAT/USDT:USDT
# scan SUN/USDT:USDT
# scan DOGS/USDT:USDT
# scan MBOX/USDT:USDT
# scan FLUX/USDT:USDT
# scan RPL/USDT:USDT
# scan POL/USDT:USDT
# scan 1MBABYDOGE/USDT:USDT
# scan NEIRO/USDT:USDT
# scan FIDA/USDT:USDT
# scan FIO/USDT:USDT
# scan CATI/USDT:USDT
# scan HMSTR/USDT:USDT
# scan COS/USDT:USDT
# scan EIGEN/USDT:USDT
# scan DIA/USDT:USDT
# scan 1000CAT/USDT:USDT
# scan SCR/USDT:USDT
# scan GOAT/USDT:USDT
# scan MOODENG/USDT:USDT
# scan SAFE/USDT:USDT
# scan SANTOS/USDT:USDT
# scan COW/USDT:USDT
# scan CETUS/USDT:USDT
# scan 1000000MOG/USDT:USDT
# scan GRASS/USDT:USDT
# scan DRIFT/USDT:USDT
# scan ACT/USDT:USDT
# scan PNUT/USDT:USDT
# scan HIPPO/USDT:USDT
# scan DEGEN/USDT:USDT
# scan BAN/USDT:USDT
    ohlcv = exchange.fetch_ohlcv(symbol, timeframe=timeframe, limit=limit)

    df = pd.DataFrame(ohlcv, columns=[
        'timestamp','open','high','low','close','volume'
    ])

    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    return df

# %%
import pandas as pd
import numpy as np

def add_rsi_tradingview(df, length=14, source_col='close'):
    """
    TradingView / Pine Script RSI implementation using RMA (Wilder)
    """

    # 1. Price change (ta.change)
    change = df[source_col].diff()

    # 2. Up & Down series
    up = change.clip(lower=0)
    down = -change.clip(upper=0)

    # 3. Wilder's Moving Average (RMA)
    alpha = 1 / length
    avg_up = up.ewm(alpha=alpha, adjust=False).mean()
    avg_down = down.ewm(alpha=alpha, adjust=False).mean()

    # 4. RSI calculation
    rs = avg_up / avg_down
    rsi = np.where(
        avg_down == 0, 100,
        np.where(avg_up == 0, 0, 100 - (100 / (1 + rs)))
    )

    df['rsi'] = rsi
    return df

# %%
def add_stochastic_tv(df, periodK=14, smoothK=3, periodD=3):
    
    # Raw stochastic
    low_min = df['low'].rolling(periodK).min()
    high_max = df['high'].rolling(periodK).max()
    
    stoch = 100 * (df['close'] - low_min) / (high_max - low_min)
    
    # Smooth K
    k = stoch.rolling(smoothK).mean()
    
    # Smooth D
    d = k.rolling(periodD).mean()
    
    df['stoch_k'] = k
    df['stoch_d'] = d
    
    return df

# %%
def add_stoch_rsi_tv(df, lengthRSI=14, lengthStoch=14, smoothK=3, smoothD=3):

    # --- TRUE TradingView RSI (RMA based)
    delta = df['close'].diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)

    alpha = 1 / lengthRSI
    avg_gain = gain.ewm(alpha=alpha, adjust=False).mean()
    avg_loss = loss.ewm(alpha=alpha, adjust=False).mean()

    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))

    # --- TRUE Stochastic of RSI
    rsi_min = rsi.rolling(lengthStoch).min()
    rsi_max = rsi.rolling(lengthStoch).max()

    stoch = 100 * (rsi - rsi_min) / (rsi_max - rsi_min)

    # --- Smooth K and D
    k = stoch.rolling(smoothK).mean()
    d = k.rolling(smoothD).mean()

    df['stoch_rsi_k'] = k
    df['stoch_rsi_d'] = d

    return df

# %%
def check_signal(df):
    last = df.iloc[-1]

    rsi = last["rsi"]
    stoch_rsi = last["stoch_rsi_k"]
    stoch_k = last["stoch_d"]

    # =========================
    # LONG CONDITIONS
    # =========================
    oversold = (
        rsi < 45 and
        stoch_rsi < 45 and
        stoch_k < 45
    )

    momentum_up = stoch_k > stoch_rsi

    long_signal = oversold and momentum_up

    # =========================
    # SHORT CONDITIONS (OPPOSITE)
    # =========================
    overbought = (
        rsi > 55 and
        stoch_rsi > 55 and
        stoch_k > 55
    )

    momentum_down = stoch_k < stoch_rsi

    short_signal = overbought and momentum_down

    if long_signal:
        return "LONG"
    elif short_signal:
        return "SHORT"
    else:
        return None

# %%
timeframes = ['15m', '1h', '4h', '1d']

def analyze_symbol(symbol):
    long_agree = []
    short_agree = []

    for tf in timeframes:
        try:
            df = get_ohlcv(symbol, tf, 500)
            df = df.iloc[:-1]

            df = add_rsi_tradingview(df)
            df = add_stochastic_tv(df, 14, 3, 3)
            df = add_stoch_rsi_tv(df, 14, 14, 3, 3)

            signal = check_signal(df)

            if signal == "LONG":
                long_agree.append(tf)

            if signal == "SHORT":
                short_agree.append(tf)

        except Exception as e:
            print(f"Error {symbol} {tf}: {e}")

    return long_agree, short_agree

# %%
def scan_market(pairs):
    results = {}

    for i, symbol in enumerate(pairs, 1):
        print(f"[{i}/{len(pairs)}] Scanning {symbol}...")

        long_agree, short_agree = analyze_symbol(symbol)

        # ===== LONG =====
        if len(long_agree) >= 2:
            print(f"🚀 LONG SIGNAL FOUND!")
            print(f"   Symbol: {symbol}")
            print(f"   Agreeing TFs ({len(long_agree)}): {', '.join(long_agree)}")
            print("-" * 40)

            results.setdefault(symbol, {})
            results[symbol]["LONG"] = long_agree

        # ===== SHORT =====
        if len(short_agree) >= 2:
            print(f"🔻 SHORT SIGNAL FOUND!")
            print(f"   Symbol: {symbol}")
            print(f"   Agreeing TFs ({len(short_agree)}): {', '.join(short_agree)}")
            print("-" * 40)

            results.setdefault(symbol, {})
            results[symbol]["SHORT"] = short_agree

    return results

# %%
signals = scan_market(filtered_pairs)

print("\n=== FINAL SUMMARY ===")
for symbol, sides in signals.items():
    for side, tfs in sides.items():
        print(f"{symbol} → {side} → {', '.join(tfs)}")
# Out:
# [1/212] Scanning BTC/USDT:USDT...
# [2/212] Scanning ETH/USDT:USDT...
# [3/212] Scanning BCH/USDT:USDT...
# [4/212] Scanning XRP/USDT:USDT...
# [5/212] Scanning LTC/USDT:USDT...
# [6/212] Scanning TRX/USDT:USDT...
# [7/212] Scanning ETC/USDT:USDT...
# [8/212] Scanning LINK/USDT:USDT...
# [9/212] Scanning XLM/USDT:USDT...
# [10/212] Scanning ADA/USDT:USDT...
# [11/212] Scanning XMR/USDT:USDT...
# [12/212] Scanning DASH/USDT:USDT...
# [13/212] Scanning ZEC/USDT:USDT...
# [14/212] Scanning XTZ/USDT:USDT...
# [15/212] Scanning BNB/USDT:USDT...
# [16/212] Scanning ATOM/USDT:USDT...
# [17/212] Scanning ONT/USDT:USDT...
# [18/212] Scanning VET/USDT:USDT...
# [19/212] Scanning ALGO/USDT:USDT...
# 🚀 LONG SIGNAL FOUND!
#    Symbol: ALGO/USDT:USDT
#    Agreeing TFs (2): 15m, 1d
# ----------------------------------------
# [20/212] Scanning ZIL/USDT:USDT...
# [21/212] Scanning COMP/USDT:USDT...
# [22/212] Scanning DOGE/USDT:USDT...
# [23/212] Scanning SNX/USDT:USDT...
# [24/212] Scanning DOT/USDT:USDT...
# [25/212] Scanning CRV/USDT:USDT...
# [26/212] Scanning TRB/USDT:USDT...
# [27/212] Scanning SOL/USDT:USDT...
# [28/212] Scanning STORJ/USDT:USDT...
# [29/212] Scanning UNI/USDT:USDT...
# [30/212] Scanning AVAX/USDT:USDT...
# [31/212] Scanning KSM/USDT:USDT...
# [32/212] Scanning NEAR/USDT:USDT...
# [33/212] Scanning AAVE/USDT:USDT...
# [34/212] Scanning FIL/USDT:USDT...
# [35/212] Scanning AXS/USDT:USDT...
# [36/212] Scanning ZEN/USDT:USDT...
# [37/212] Scanning GRT/USDT:USDT...
# [38/212] Scanning CHZ/USDT:USDT...
# 🚀 LONG SIGNAL FOUND!
#    Symbol
USDT:USDT...
# 🔻 SHORT SIGNAL FOUND!
#    Symbol: FOGO/USDT:USDT
#    Agreeing TFs (2): 15m, 1h
# ----------------------------------------
# [192/212] Scanning 我踏马来了/USDT:USDT...
# [193/212] Scanning ELSA/USDT:USDT...
# 🔻 SHORT SIGNAL FOUND!
#    Symbol: ELSA/USDT:USDT
#    Agreeing TFs (2): 1h, 4h
# ----------------------------------------
# [194/212] Scanning SKR/USDT:USDT...
# [195/212] Scanning SPACE/USDT:USDT...
# [196/212] Scanning FIGHT/USDT:USDT...
# [197/212] Scanning TSLA/USDT:USDT...
# [198/212] Scanning BIRB/USDT:USDT...
# [199/212] Scanning GWEI/USDT:USDT...
# [200/212] Scanning XPT/USDT:USDT...
# 🔻 SHORT SIGNAL FOUND!
#    Symbol: XPT/USDT:USDT
#    Agreeing TFs (2): 15m, 1h
# ----------------------------------------
# [201/212] Scanning XPD/USDT:USDT...
# 🔻 SHORT SIGNAL FOUND!
#    Symbol: XPD/USDT:USDT
#    Agreeing TFs (2): 4h, 1d
# ----------------------------------------
# [202/212] Scanning INX/USDT:USDT...
# [203/212] Scanning INTC/USDT:USDT...
# [204/212] Scanning HOOD/USDT:USDT...
# [205/212] Scanning TRIA/USDT:USDT...
# [206/212] Scanning MSTR/USDT:USDT...
# [207/212] Scanning AMZN/USDT:USDT...
# [208/212] Scanning CRCL/USDT:USDT...
# [209/212] Scanning COIN/USDT:USDT...
# [210/212] Scanning ESP/USDT:USDT...
# [211/212] Scanning AZTEC/USDT:USDT...
# [212/212] Scanning OPN/USDT:USDT...
#
# === FINAL SUMMARY ===
# ALGO/USDT:USDT → LONG → 15m, 1d
# CHZ/USDT:USDT → LONG → 15m, 1d
# OP/USDT:USDT → LONG → 15m, 1d
# STG/USDT:USDT → LONG → 15m, 1d
# ACH/USDT:USDT → LONG → 15m, 1d
# ARB/USDT:USDT → LONG → 15m, 1d
# PENDLE/USDT:USDT → SHORT → 1h, 4h
# GAS/USDT:USDT → SHORT → 1h, 4h
# TON/USDT:USDT → LONG → 15m, 4h, 1d
# ZRO/USDT:USDT → LONG → 15m, 1d
# MORPHO/USDT:USDT → SHORT → 4h, 1d
# ORCA/USDT:USDT → LONG → 15m, 4h
# ARC/USDT:USDT → SHORT → 4h, 1d
# SIREN/USDT:USDT → SHORT → 15m, 1h, 4h, 1d
# KERNEL/USDT:USDT → SHORT → 4h, 1d
# SXT/USDT:USDT → LONG → 15m, 1h
# HYPE/USDT:USDT → LONG → 15m, 1d
# MYX/USDT:USDT → LONG → 4h, 1d
# PUMP/USDT:USDT → LONG → 15m, 1d
# AIN/USDT:USDT → SHORT → 4h, 1d
# DAM/USDT:USDT → SHORT → 15m, 4h, 1d
# LINEA/USDT:USDT → LONG → 15m, 4h
# AKE/USDT:USDT → SHORT → 4h, 1d
# LYN/USDT:USDT → SHORT → 15m, 1h
# ENSO/USDT:USDT → SHORT → 15m, 1d
# RIVER/USDT:USDT → SHORT → 15m, 4h
# 币安人生/USDT:USDT → LONG → 15m, 1d
# GUA/USDT:USDT → SHORT → 4h, 1d
# FOGO/USDT:USDT → SHORT → 15m, 1h
# ELSA/USDT:USDT → SHORT → 1h, 4h
# XPT/USDT:USDT → SHORT → 15m, 1h
# XPD/USDT:USDT → SHORT → 4h, 1d
